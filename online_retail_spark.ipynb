# %% [markdown]
# # Predicting order cancellations using getML
#
#
# In this tutorial, we demonstrate how getML can be applied in an e-commerce context. Using a dataset of about 400,000 orders, our goal is to predict whether an order will be cancelled.
#
# We also show that we can significantly improve our results by using getML's built-in hyperparameter tuning routines.
#
# Summary:
#
# - Prediction type: __Classification model__
# - Domain: __E-commerce__
# - Prediction target: __Whether an order will be cancelled__
# - Population size: __397925__
#
# _Author: Dr. Patrick Urbanke_

# %% [markdown]
# # Background
#
# The data set contains about 400,000 orders from a British online retailer. Each order consists of a product that has been ordered and a corresponding quantity. Several orders can be summarized onto a single invoice. The goal is to predict whether an order will be cancelled.
#
# Because the company mainly sells to other businesses, the cancellation rate is relatively low, namely 1.83%.
#
# The data set has been originally collected for this study:
#
# > Daqing Chen, Sai Liang Sain, and Kun Guo, Data mining for the online retail industry: A case study of RFM model-based customer segmentation using data mining, Journal of Database Marketing and Customer Strategy Management, Vol. 19, No. 3, pp. 197-208, 2012 (Published online before print: 27 August 2012. doi: 10.1057/dbm.2012.17).
#
# It has been downloaded from the UCI Machine Learning Repository:
#
# > Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.

# %% [markdown]
# ### A web frontend for getML
#
# The getML monitor is a frontend built to support your work with getML. The getML monitor displays information such as the imported data frames, trained pipelines and allows easy data and feature exploration. You can launch the getML monitor [here](http://localhost:1709).

# %% [markdown]
# ### Where is this running?
#
# Your getML live session is running inside a docker container on [mybinder.org](https://mybinder.org/), a service built by the Jupyter community and funded by Google Cloud, OVH, GESIS Notebooks and the Turing Institute. As it is a free service, this session will shut down after 10 minutes of inactivity.

# %% [markdown]
# # Analysis

# %% [markdown]
# Let's get started with the analysis and set up your session:

# %%
import copy
import os
from urllib import request

import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline  

from pyspark.sql import SparkSession
import getml

getml.engine.set_project('online_retail')
# Out:
# Connected to project 'online_retail'

# %% [markdown]
# Tuning is effective at improving our results, but it takes quite long, so we want to make it optional:

# %% [markdown]
# ## 1. Loading data

# %% [markdown]
# ### 1.1 Download from source
#
# We begin by downloading the data from the source file:

# %%
fname = "online_retail.csv"

if not os.path.exists(fname):
    fname, res = request.urlretrieve(
        "https://static.getml.com/datasets/online_retail/" + fname, 
        fname
    )
    
full_data_pandas = pd.read_csv(fname, sep="|")

# %% [markdown]
# ### 1.2 Data preparation
#
# The invoice dates are in a somewhat unusual format, fo we need to rectify that.

# %%
def add_zero(string):
    if len(string) == 1:
        return "0" + string
    return string

# %%
def format_date(string):
    datetime = string.split(" ")
    assert len(datetime) == 2, "Expected date and time"
    
    date_components = datetime[0].split("/")
    assert len(date_components) == 3, "Expected three date components"
    
    date_components = [add_zero(x) for x in date_components]
    
    return "-".join(date_components) + " " + datetime[1]

# %%
full_data_pandas["InvoiceDate"] = [
    format_date(string) for string in np.asarray(full_data_pandas["InvoiceDate"])
]

# %%
full_data_pandas
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#              InvoiceDate  Price  Customer ID         Country
# 0       2010-12-01 08:26   2.55      17850.0  United Kingdom
# 1       2010-12-01 08:26   3.39      17850.0  United Kingdom
# 2       2010-12-01 08:26   2.75      17850.0  United Kingdom
# 3       2010-12-01 08:26   3.39      17850.0  United Kingdom
# 4       2010-12-01 08:26   3.39      17850.0  United Kingdom
# ...                  ...    ...          ...             ...
# 541905  2011-12-09 12:50   2.10      12680.0          France
# 541906  2011-12-09 12:50   4.15      12680.0          France
# 541907  2011-12-09 12:50   4.15      12680.0          France
# 541908  2011-12-09 12:50   4.95      12680.0          France
# 541909  2011-12-09 12:50  18.00      12680.0          France
#
# [541910 rows x 8 columns]

# %% [markdown]
# In this data set, the targets aren't as clearly defined as we would like to, so we have do define them ourselves.

# %%
def add_target(df):
    df = df.sort_values(by=["Customer ID", "InvoiceDate"])
    
    cancelled = np.zeros(df.shape[0])

    invoice = np.asarray(df["Invoice"])
    stock_code = np.asarray(df["StockCode"])
    customer_id = np.asarray(df["Customer ID"])

    for i in range(len(invoice)):
        if (invoice[i][0] == 'C') or (i == len(invoice) - 1):
            continue

        j = i + 1

        while customer_id[j] == customer_id[i]:
            if (invoice[j][0] == 'C') and (stock_code[i] == stock_code[j]):
                cancelled[i] = 1.0
                break

            if stock_code[i] == stock_code[j]:
                break

            j += 1
    
    df["cancelled"] = cancelled
    
    return df

# %% [markdown]
# Also, we want to remove any orders in the data set that are actually cancellations.

# %%
def remove_cancellations(df):
    invoice = np.asarray(df["Invoice"])

    is_order = [inv[0] != 'C' for inv in invoice]
    
    df = df[is_order]
    
    return df

# %%
full_data_pandas = add_target(full_data_pandas)
full_data_pandas = remove_cancellations(full_data_pandas)

# %% [markdown]
# Finally, there are some order for which we do not have a customer ID. We want to remove those.

# %%
full_data_pandas = full_data_pandas[~np.isnan(full_data_pandas["Customer ID"])]

# %% [markdown]
# Now we can upload the data to getML.

# %%
full_data = getml.data.DataFrame.from_pandas(full_data_pandas, "full_data")

full_data
# Out:
#   name       Quantity          Price    Customer ID      cancelled   Invoice         StockCode
#   role   unused_float   unused_float   unused_float   unused_float   unused_string   unused_string
#      0          74215           1.04          12346              1   541431          23166
#      1             12           2.1           12347              0   537626          85116
#      2              4           4.25          12347              0   537626          22375
#      3             12           3.25          12347              0   537626          71477
#      4             36           0.65          12347              0   537626          22492
#                   ...          ...              ...            ...   ...             ...
# 397920             12           0.42          18287              0   570715          22419
# 397921             12           2.1           18287              0   570715          22866
# 397922             36           1.25          18287              0   573167          23264
# 397923             48           0.39          18287              0   573167          21824
# 397924             24           0.29          18287              0   573167          21014
#
#   name   Description                        InvoiceDate        Country
#   role   unused_string                      unused_string      unused_string
#      0   MEDIUM CERAMIC TOP STORAGE JAR     2011-01-18 10:01   United Kingdom
#      1   BLACK CANDELABRA T-LIGHT HOLDER    2010-12-07 14:57   Iceland
#      2   AIRLINE BAG VINTAGE JET SET BROW...   2010-12-07 14:57   Iceland
#      3   COLOUR GLASS. STAR T-LIGHT HOLDE...   2010-12-07 14:57   Iceland
#      4   MINI PAINT SET VINTAGE             2010-12-07 14:57   Iceland
#          ...                                ...                ...
# 397920   LIPSTICK PEN RED                   2011-10-12 10:23   United Kingdom
# 397921   HAND WARMER SCOTTY DOG DESIGN      2011-10-12 10:23   United Kingdom
# 397922   SET OF 3 WOODEN SLEIGH DECORATIO...   2011-10-28 09:29   United Kingdom
# 397923   PAINTED METAL STAR WITH HOLLY BE...   2011-10-28 09:29   United Kingdom
# 397924   SWISS CHALET TREE DECORATION       2011-10-28 09:29   United Kingdom
#
#
# 397925 rows x 9 columns
# memory usage: 57.28 MB
# name: full_data
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/online_retail/full_data/

# %% [markdown]
# ### 1.3 Prepare data for getML

# %% [markdown]
# getML requires that we define *roles* for each of the columns.

# %%
full_data.set_role("InvoiceDate", getml.data.roles.time_stamp, time_formats=['%Y-%m-%d %H:%M'])
full_data.set_role(["Customer ID", "Invoice"], getml.data.roles.join_key)
full_data.set_role(["cancelled"], getml.data.roles.target)
full_data.set_role(["Quantity", "Price"], getml.data.roles.numerical)
full_data.set_role("Country", getml.data.roles.categorical)
full_data.set_role("Description", getml.data.roles.text)

# %% [markdown]
# The *StockCode* is a 5-digit code that uniquely defines a product. It is hierarchical, meaning that every digit has a meaning. We want to make use of that, so we assign a unit to the stock code, which we can reference in our preprocessors.

# %%
full_data.set_unit("StockCode", "code")

# %%
split = getml.data.split.random(train=0.7, validation=0.15, test=0.15)
split
# Out:
#
#  0   train
#  1   validation
#  2   train
#  3   validation
#  4   validation
#      ...
#
#
# infinite number of  rows
# type: StringColumnView

# %% [markdown]
# ## 2. Predictive modeling
#
# We loaded the data and defined the roles and units. Next, we create a getML pipeline for relational learning.

# %% [markdown]
# ### 2.1 Define relational model
#
# To get started with relational learning, we need to specify the data model.
#
# In our case, there are two joins we are interested in:
#
# 1) We want to take a look at all of the other orders on the same invoice.
#
# 2) We want to check out how often a certain customer has cancelled orders in the past. Here, we limit ourselves to the last 90 days. To avoid data leaks, we set a horizon of one day.

# %%
star_schema = getml.data.StarSchema(
    population=full_data, 
    alias="population",
    split=split,
)

star_schema.join(
    full_data.drop("Description"),
    alias="full_data",
    on='Invoice',
)

star_schema.join(
    full_data.drop("Description"),
    alias="full_data",
    on='Customer ID',
    time_stamps='InvoiceDate',
    horizon=getml.data.time.days(1),
    memory=getml.data.time.days(90),
    lagged_targets=True,
)

star_schema
# Out:
# data model
#
#   population:
#     columns:
#     - Country: categorical
#     - Customer ID: join_key
#     - Invoice: join_key
#     - Quantity: numerical
#     - Price: numerical
#     - ...
#
#     joins:
#     - right: 'full_data'
#       on: (population.Invoice, full_data.Invoice)
#       relationship: 'many-to-many'
#       lagged_targets: False
#     - right: 'full_data'
#       on: (population.Customer ID, full_data.Customer ID)
#       time_stamps: (population.InvoiceDate, full_data.InvoiceDate)
#       relationship: 'many-to-many'
#       memory: 7776000.0
#       horizon: 86400.0
#       lagged_targets: True
#
#   full_data:
#     columns:
#     - Country: categorical
#     - Customer ID: join_key
#     - Invoice: join_key
#     - Quantity: numerical
#     - Price: numerical
#     - ...
#
#   full_data:
#     columns:
#     - Country: categorical
#     - Customer ID: join_key
#     - Invoice: join_key
#     - Quantity: numerical
#     - Price: numerical
#     - ...
#
#
# container
#
#   population
#       subset       name          rows   type
#   0   test         full_data    60013   View
#   1   train        full_data   278171   View
#   2   validation   full_data    59741   View
#
#   peripheral
#       name          rows   type
#   0   full_data   397925   View

# %% [markdown]
# ### 2.2 getML pipeline

# %% [markdown]
# <!-- #### 2.1.1  -->
# __Set-up the feature learner & predictor__

# %% [markdown]
# We have mentioned that the *StockCode* is a hierarchical code. To make use of that fact, we use getML's substring preprocessor, extracting the first digit, the first two digits etc. Since we have assigned the unit *code* to the *StockCode*, the preprocessors know which column they should be applied to.

# %%
substr1 = getml.preprocessors.Substring(0, 1, "code")
substr2 = getml.preprocessors.Substring(0, 2, "code")
substr3 = getml.preprocessors.Substring(0, 3, "code")

mapping = getml.preprocessors.Mapping()

fast_prop = getml.feature_learning.FastProp(
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
    num_threads=1,
    sampling_factor=0.1,
)

feature_selector = getml.predictors.XGBoostClassifier()

predictor = getml.predictors.XGBoostClassifier()

# %% [markdown]
# __Build the pipeline__

# %%
pipe = getml.pipeline.Pipeline(
    tags=['fast_prop'],
    data_model=star_schema.data_model,
    preprocessors=[substr1, substr2, substr3, mapping],
    feature_learners=[fast_prop],
    feature_selectors=[feature_selector],
    predictors=[predictor],
    share_selected_features=0.2,
)

pipe
# Out:
# Pipeline(data_model='population',
#          feature_learners=['FastProp'],
#          feature_selectors=['XGBoostClassifier'],
#          include_categorical=False,
#          loss_function=None,
#          peripheral=['full_data'],
#          predictors=['XGBoostClassifier'],
#          preprocessors=['Substring', 'Substring', 'Substring', 'Mapping'],
#          share_selected_features=0.2,
#          tags=['fast_prop'])

# %% [markdown]
# ### 2.3 Model training

# %%
pipe.check(star_schema.train)
# Out:
# Checking data model...
#
#
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# Checking...
# [========================================] 100%
#
#
# OK.

# %%
pipe.fit(star_schema.train)
# Out:
# Checking data model...
#
#
# Staging...
# [========================================] 100%
#
#
# OK.
#
#
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# Indexing text fields...
# [========================================] 100%
#
# FastProp: Trying 196 features...
# [========================================] 100%
#
# FastProp: Building features...
# [========================================] 100%
#
# XGBoost: Training as feature selector...
# [========================================] 100%
#
# XGBoost: Training as predictor...
# [========================================] 100%
#
#
# Trained pipeline.
# Time taken: 0h:4m:46.121703
# Pipeline(data_model='population',
#          feature_learners=['FastProp'],
#          feature_selectors=['XGBoostClassifier'],
#          include_categorical=False,
#          loss_function=None,
#          peripheral=['full_data'],
#          predictors=['XGBoostClassifier'],
#          preprocessors=['Substring', 'Substring', 'Substring', 'Mapping'],
#          share_selected_features=0.2,
#          tags=['fast_prop', 'container-dG3MnJ'])
#
# url: http://localhost:1709/#/getpipeline/online_retail/o4KAyo/0/

# %% [markdown]
# ### 2.4 Model evaluation

# %%
pipe.score(star_schema.test)
# Out:
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# FastProp: Building features...
# [========================================] 100%
#     date time             set used   target      accuracy       auc   cross entropy
# 0   2021-09-19 06:13:23   train      cancelled     0.9825    0.8473         0.07345
# 1   2021-09-19 06:13:30   test       cancelled     0.9826    0.8168         0.07499

# %% [markdown]
# ### 2.5 Productionization
#
# It is possible to productionize the pipeline by transpiling the features into production-ready SQL code.

# %%
pipe.features.to_sql(dialect=getml.pipeline.dialect.spark_sql).save("online_retail_spark")

# %%
spark = SparkSession.builder.appName(
    "online_retail"
).config(
    "spark.driver.maxResultSize","5g"
).config(
    "spark.driver.memory", "5g"
).config(
    "spark.sql.execution.arrow.pyspark.enabled", "true"
).config(
    "spark.sql.session.timeZone", "UTC"
).enableHiveSupport().getOrCreate()
# Out:
# 21/09/19 06:13:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
population_spark = star_schema.train.population.to_pyspark(spark, name="population")
peripheral_spark = star_schema.full_data.to_pyspark(spark, name="full_data")

# %%
getml.spark.execute(spark, "online_retail_spark")
# Out:
# 2021-09-19 06:13:48,698 Executing online_retail_spark/0001_population__staging_table_1.sql...
# 21/09/19 06:13:49 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 21/09/19 06:13:49 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 21/09/19 06:13:54 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 21/09/19 06:13:54 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore patrick@192.168.178.61
# 21/09/19 06:13:54 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:13:54 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# 21/09/19 06:13:54 WARN HiveConf: HiveConf of name hive.internal.ss.authz.settings.applied.marker does not exist
# 21/09/19 06:13:54 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 21/09/19 06:13:54 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 21/09/19 06:13:54 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/population__staging_table_1 specified for non-external table:population__staging_table_1
# 21/09/19 06:13:59 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException
# 2021-09-19 06:13:59,218 Executing online_retail_spark/0002_full_data__staging_table_2.sql...
# 21/09/19 06:13:59 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:13:59 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/full_data__staging_table_2 specified for non-external table:full_data__staging_table_2
# 2021-09-19 06:14:00,729 Executing online_retail_spark/0003_country__mapping_1_target_1_avg.sql...
# 21/09/19 06:14:00 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:00 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/country__mapping_1_target_1_avg specified for non-external table:country__mapping_1_target_1_avg
# 21/09/19 06:14:01 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:01 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/full_data__staging_table_2 specified for non-external table:full_data__staging_table_2
# 2021-09-19 06:14:04,850 Executing online_retail_spark/0004_quantity__mapping_1_target_1_avg.sql...
# 21/09/19 06:14:04 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:04 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/quantity__mapping_1_target_1_avg specified for non-external table:quantity__mapping_1_target_1_avg
# 21/09/19 06:14:05 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:05 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/full_data__staging_table_2 specified for non-external table:full_data__staging_table_2
# 2021-09-19 06:14:07,897 Executing online_retail_spark/0005_country__mapping_2_target_1_avg.sql...
# 21/09/19 06:14:07 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:07 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/country__mapping_2_target_1_avg specified for non-external table:country__mapping_2_target_1_avg
# 21/09/19 06:14:08 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:08 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/full_data__staging_table_2 specified for non-external table:full_data__staging_table_2
# 2021-09-19 06:14:10,704 Executing online_retail_spark/0006_quantity__mapping_2_target_1_avg.sql...
# 21/09/19 06:14:10 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:10 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/quantity__mapping_2_target_1_avg specified for non-external table:quantity__mapping_2_target_1_avg
# 21/09/19 06:14:11 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:11 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/full_data__staging_table_2 specified for non-external table:full_data__staging_table_2
# 2021-09-19 06:14:13,534 Executing online_retail_spark/0007_country__mapping_target_1_avg.sql...
# 21/09/19 06:14:13 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:13 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/country__mapping_target_1_avg specified for non-external table:country__mapping_target_1_avg
# 21/09/19 06:14:14 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:14 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/population__staging_table_1 specified for non-external table:population__staging_table_1
# 2021-09-19 06:14:15,925 Executing online_retail_spark/0008_quantity__mapping_target_1_avg.sql...
# 21/09/19 06:14:15 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:15 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/quantity__mapping_target_1_avg specified for non-external table:quantity__mapping_target_1_avg
# 21/09/19 06:14:16 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:16 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/population__staging_table_1 specified for non-external table:population__staging_table_1
# 2021-09-19 06:14:18,299 Executing online_retail_spark/0009_description__mapping_target_1_avg.sql...
# 21/09/19 06:14:18 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:18 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/description__mapping_target_1_avg specified for non-external table:description__mapping_target_1_avg
# 21/09/19 06:14:19 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:14:19 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/population__staging_table_1 specified for non-external table:population__staging_table_1
# 2021-09-19 06:17:19,169 Executing online_retail_spark/0010_feature_1_2.sql...
# 21/09/19 06:17:19 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:19 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_2 specified for non-external table:feature_1_2
# 2021-09-19 06:17:24,362 Executing online_retail_spark/0011_feature_1_3.sql...
# 21/09/19 06:17:24 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:24 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_3 specified for non-external table:feature_1_3
# 2021-09-19 06:17:27,765 Executing online_retail_spark/0012_feature_1_4.sql...
# 21/09/19 06:17:27 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:27 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_4 specified for non-external table:feature_1_4
# 2021-09-19 06:17:32,677 Executing online_retail_spark/0013_feature_1_5.sql...
# 21/09/19 06:17:32 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:32 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_5 specified for non-external table:feature_1_5
# 2021-09-19 06:17:37,588 Executing online_retail_spark/0014_feature_1_7.sql...
# 21/09/19 06:17:37 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:37 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_7 specified for non-external table:feature_1_7
# 2021-09-19 06:17:48,558 Executing online_retail_spark/0015_feature_1_14.sql...
# 21/09/19 06:17:48 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:48 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_14 specified for non-external table:feature_1_14
# 2021-09-19 06:17:53,814 Executing online_retail_spark/0016_feature_1_16.sql...
# 21/09/19 06:17:53 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:17:53 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_16 specified for non-external table:feature_1_16
# 2021-09-19 06:18:03,928 Executing online_retail_spark/0017_feature_1_17.sql...
# 21/09/19 06:18:03 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:03 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_17 specified for non-external table:feature_1_17
# 2021-09-19 06:18:07,322 Executing online_retail_spark/0018_feature_1_20.sql...
# 21/09/19 06:18:07 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:07 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_20 specified for non-external table:feature_1_20
# 2021-09-19 06:18:10,890 Executing online_retail_spark/0019_feature_1_21.sql...
# 21/09/19 06:18:10 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:10 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_21 specified for non-external table:feature_1_21
# 2021-09-19 06:18:14,377 Executing online_retail_spark/0020_feature_1_28.sql...
# 21/09/19 06:18:14 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:14 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_28 specified for non-external table:feature_1_28
# 2021-09-19 06:18:17,878 Executing online_retail_spark/0021_feature_1_29.sql...
# 21/09/19 06:18:17 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:17 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_29 specified for non-external table:feature_1_29
# 2021-09-19 06:18:21,318 Executing online_retail_spark/0022_feature_1_30.sql...
# 21/09/19 06:18:21 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:21 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_30 specified for non-external table:feature_1_30
# 2021-09-19 06:18:24,823 Executing online_retail_spark/0023_feature_1_34.sql...
# 21/09/19 06:18:24 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:24 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_34 specified for non-external table:feature_1_34
# 2021-09-19 06:18:34,570 Executing online_retail_spark/0024_feature_1_38.sql...
# 21/09/19 06:18:34 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:34 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_38 specified for non-external table:feature_1_38
# 2021-09-19 06:18:37,769 Executing online_retail_spark/0025_feature_1_48.sql...
# 21/09/19 06:18:37 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:37 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_48 specified for non-external table:feature_1_48
# 2021-09-19 06:18:41,103 Executing online_retail_spark/0026_feature_1_55.sql...
# 21/09/19 06:18:41 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:41 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_55 specified for non-external table:feature_1_55
# 2021-09-19 06:18:44,561 Executing online_retail_spark/0027_feature_1_56.sql...
# 21/09/19 06:18:44 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:44 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_56 specified for non-external table:feature_1_56
# 2021-09-19 06:18:47,992 Executing online_retail_spark/0028_feature_1_95.sql...
# 21/09/19 06:18:48 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:18:48 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_95 specified for non-external table:feature_1_95
# 2021-09-19 06:19:11,364 Executing online_retail_spark/0029_feature_1_96.sql...
# 21/09/19 06:19:11 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:11 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_96 specified for non-external table:feature_1_96
# 2021-09-19 06:19:17,218 Executing online_retail_spark/0030_feature_1_103.sql...
# 21/09/19 06:19:17 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:17 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_103 specified for non-external table:feature_1_103
# 2021-09-19 06:19:30,346 Executing online_retail_spark/0031_feature_1_111.sql...
# 21/09/19 06:19:30 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:30 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_111 specified for non-external table:feature_1_111
# 2021-09-19 06:19:36,113 Executing online_retail_spark/0032_feature_1_120.sql...
# 21/09/19 06:19:36 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:36 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_120 specified for non-external table:feature_1_120
# 2021-09-19 06:19:42,407 Executing online_retail_spark/0033_feature_1_134.sql...
# 21/09/19 06:19:42 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:42 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_134 specified for non-external table:feature_1_134
# 2021-09-19 06:19:48,484 Executing online_retail_spark/0034_feature_1_135.sql...
# 21/09/19 06:19:48 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:48 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_135 specified for non-external table:feature_1_135
# 2021-09-19 06:19:53,930 Executing online_retail_spark/0035_feature_1_139.sql...
# 21/09/19 06:19:53 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:19:54 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_139 specified for non-external table:feature_1_139
# 2021-09-19 06:20:06,966 Executing online_retail_spark/0036_feature_1_147.sql...
# 21/09/19 06:20:06 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:07 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_147 specified for non-external table:feature_1_147
# 2021-09-19 06:20:11,929 Executing online_retail_spark/0037_feature_1_159.sql...
# 21/09/19 06:20:11 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:11 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_159 specified for non-external table:feature_1_159
# 2021-09-19 06:20:17,886 Executing online_retail_spark/0038_feature_1_168.sql...
# 21/09/19 06:20:17 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:17 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_168 specified for non-external table:feature_1_168
# 2021-09-19 06:20:23,201 Executing online_retail_spark/0039_feature_1_169.sql...
# 21/09/19 06:20:23 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:23 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_169 specified for non-external table:feature_1_169
# 2021-09-19 06:20:29,131 Executing online_retail_spark/0040_feature_1_170.sql...
# 21/09/19 06:20:29 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:29 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_170 specified for non-external table:feature_1_170
# 2021-09-19 06:20:35,313 Executing online_retail_spark/0041_feature_1_175.sql...
# 21/09/19 06:20:35 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:35 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_175 specified for non-external table:feature_1_175
# 2021-09-19 06:20:49,001 Executing online_retail_spark/0042_feature_1_177.sql...
# 21/09/19 06:20:49 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:20:49 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_177 specified for non-external table:feature_1_177
# 2021-09-19 06:21:03,487 Executing online_retail_spark/0043_feature_1_181.sql...
# 21/09/19 06:21:03 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:21:03 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_181 specified for non-external table:feature_1_181
# 2021-09-19 06:21:09,342 Executing online_retail_spark/0044_feature_1_193.sql...
# 21/09/19 06:21:09 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:21:09 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/feature_1_193 specified for non-external table:feature_1_193
# 2021-09-19 06:21:15,105 Executing online_retail_spark/0045_features.sql...
# 21/09/19 06:21:15 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 21/09/19 06:21:15 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 21/09/19 06:21:15 WARN HiveMetaStore: Location: file:/home/patrick/getml-demo/spark-warehouse/features specified for non-external table:features

# %% [markdown]
# ## 3. Conclusion
#
# In this notebook we have demonstrated how getML can be applied to an e-commerce setting. In particular, we have seen how results can be improved using the built-in hyperparamater tuning routines.

# %% [markdown]
# # Next Steps
#
# This tutorial presented an application of getML in the e-commerce context.
#
# If you are interested in further real-world applications of getML, head back to the [notebook overview](welcome.md) and choose one of the remaining examples.
#
# Here is some additional material from our [documentation](https://docs.getml.com/latest/) if you want to learn more about getML:
# * [Feature learning with Multirel](https://docs.getml.com/latest/user_guide/feature_engineering/feature_engineering.html#multirel)
# * [Feature learning with Relboost](https://docs.getml.com/latest/user_guide/feature_engineering/feature_engineering.html#relboost)

# %% [markdown]
# # Get in contact
#
# If you have any question schedule a [call with Alex](https://go.getml.com/meetings/alexander-uhlig/getml-demo), the co-founder of getML, or write us an [email](team@getml.com). Prefer a private demo of getML? Just contact us to make an appointment.
