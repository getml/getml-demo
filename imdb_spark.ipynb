# %% [markdown]
# # IMDb - Predicting actors' gender using getML
#
# **Note that due to memory limitations, this notebook will not run on MyBinder.**
#
# In this tutorial, we demonstrate how getML can be applied to text fields. In relational databases, text fields are less structured and less standardized than categorical data, making it more difficult to extract useful information from them. Therefore, they are ignored in most data science projects on relational data. However, when using a relational learning tool such as getML, we can easily generate simple features from text fields and leverage the information contained therein.
#
# The point of this exercise is not to compete with modern deep-learning-based NLP approaches. The point is to develop an approach by which we can leverage fields in relational databases that would otherwise be ignored.
#
# As an example data set, we use the Internet Movie Database, which has been used by previous studies in the relational learning literature. This allows us to benchmark our approach to state-of-the-art algorithms in the relational learning literature. We demonstrate that getML outperforms these state-of-the-art algorithms.
#
# Summary:
#
# - Prediction type: __Classification model__
# - Domain: __Entertainment__
# - Prediction target: __The gender of an actor__
# - Population size: __817718__
#
# _Author: Dr. Patrick Urbanke_

# %% [markdown]
# # Background
#
# The data set contains about 800,000 actors. The goal is to predict the gender of said actors based on other information we have about them, such as the movies they have participated in and the roles they have played in these movies.
#
# It has been downloaded from the [CTU Prague relational learning repository](https://relational.fit.cvut.cz/dataset/IMDb) (Motl and Schulte, 2015).

# %% [markdown]
# ### A web frontend for getML
#
# The getML monitor is a frontend built to support your work with getML. The getML monitor displays information such as the imported data frames, trained pipelines and allows easy data and feature exploration. You can launch the getML monitor [here](http://localhost:1709/listprojects/actors/).

# %% [markdown]
# ### Where is this running?
#
# Your getML live session is running inside a docker container on [mybinder.org](https://mybinder.org/), a service built by the Jupyter community and funded by Google Cloud, OVH, GESIS Notebooks and the Turing Institute. As it is a free service, this session will shut down after 10 minutes of inactivity.

# %% [markdown]
# # Analysis

# %% [markdown]
# Let's get started with the analysis and set up your session:

# %%
import copy
import os
from urllib import request

import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline  

import getml
import pyspark

getml.engine.set_project('imdb')
# Out:
# Loading pipelines...
# [========================================] 100%
#
# Connected to project 'imdb'

# %% [markdown]
# <span id='flags'></span>
# In the following, we set some flags that affect execution of the notebook:
# - We don't let the algorithms utilize the information on actors' first names (see [below](#first-names) for an explanation).

# %%
USE_FIRST_NAMES = False

# %% [markdown]
# ## 1. Loading data

# %% [markdown]
# ### 1.1 Download from source
#
# We begin by downloading the data from the source file:

# %%
conn = getml.database.connect_mariadb(
    host="relational.fit.cvut.cz",
    dbname="imdb_ijs",
    port=3306,
    user="guest",
    password="relational"
)

conn
# Out:
# Connection(conn_id='default',
#            dbname='imdb_ijs',
#            dialect='mysql',
#            host='relational.fit.cvut.cz',
#            port=3306)

# %%
def load_if_needed(name):
    """
    Loads the data from the relational learning
    repository, if the data frame has not already
    been loaded.
    """
    if getml.data.exists(name):
        return getml.data.load_data_frame(name)
    data_frame = getml.data.DataFrame.from_db(
        name=name,
        table_name=name,
        conn=conn
    )
    data_frame.save()
    return data_frame

# %%
actors = load_if_needed("actors")
roles = load_if_needed("roles")
movies = load_if_needed("movies")
movies_genres = load_if_needed("movies_genres")

# %%
actors
# Out:
#   name             id   first_name      last_name            gender
#   role   unused_float   unused_string   unused_string        unused_string
#      0              2   Michael         'babeepower' Viera   M
#      1              3   Eloy            'Chincheta'          M
#      2              4   Dieguito        'El Cigala'          M
#      3              5   Antonio         'El de Chipiona'     M
#      4              6   José            'El Francés'         M
#                   ...   ...             ...                  ...
# 817713         845461   Herdís          Þorvaldsdóttir       F
# 817714         845462   Katla Margrét   Þorvaldsdóttir       F
# 817715         845463   Lilja Nótt      Þórarinsdóttir       F
# 817716         845464   Hólmfríður      Þórhallsdóttir       F
# 817717         845465   Theódóra        Þórðardóttir         F
#
#
# 817718 rows x 4 columns
# memory usage: 40.14 MB
# name: actors
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/actors/

# %%
roles
# Out:
#    name       actor_id       movie_id   role
#    role   unused_float   unused_float   unused_string
#       0              2         280088   Stevie
#       1              2         396232   Various/lyricist
#       2              3         376687   Gitano 1
#       3              4         336265   El Cigala
#       4              5         135644   Himself
#                    ...            ...   ...
# 3431961         845461         137097   Kata
# 3431962         845462         208838   Magga
# 3431963         845463            870   Gunna
# 3431964         845464         378123   Gudrun
# 3431965         845465         378123
#
#
# 3431966 rows x 3 columns
# memory usage: 115.29 MB
# name: roles
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/roles/

# %%
movies
# Out:
#   name             id           year           rank   name
#   role   unused_float   unused_float   unused_float   unused_string
#      0              0           2002          nan     #28
#      1              1           2000          nan     #7 Train: An Immigrant Journey, ...
#      2              2           1971            6.4   $
#      3              3           1913          nan     $1,000 Reward
#      4              4           1915          nan     $1,000 Reward
#                   ...            ...           ...    ...
# 388264         412316           1991          nan     "zem blch krlu"
# 388265         412317           1995          nan     "rgammk"
# 388266         412318           2002          nan     "zgnm Leyla"
# 388267         412319           1983          nan     " Istanbul"
# 388268         412320           1958          nan     "sterreich"
#
#
# 388269 rows x 4 columns
# memory usage: 19.92 MB
# name: movies
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/movies/

# %%
movies_genres
# Out:
#   name       movie_id   genre
#   role   unused_float   unused_string
#      0              1   Documentary
#      1              1   Short
#      2              2   Comedy
#      3              2   Crime
#      4              5   Western
#                   ...   ...
# 395114         378612   Adventure
# 395115         378612   Drama
# 395116         378613   Comedy
# 395117         378613   Drama
# 395118         378614   Comedy
#
#
# 395119 rows x 2 columns
# memory usage: 9.24 MB
# name: movies_genres
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/movies_genres/

# %% [markdown]
# ### 1.2 Prepare data for getML

# %% [markdown]
# getML requires that we define *roles* for each of the columns.

# %%
actors["target"] = (actors.gender == 'F')
actors.set_role("id", getml.data.roles.join_key)
actors.set_role("target", getml.data.roles.target)

# %% [markdown]
# <span id='first-names'></span>
# The benchmark studies do not state clearly, whether it is fair game to use the first names of the actors. Using the first names, we can easily increase the predictive accuracy to above 90%. However, when doing so the problem basically becomes a first name identification problem rather than a relational learning problem. This would undermine the point of this notebook: Showcase relational learning. Therefore, our assumption is that using the first names is not allowed. Feel free to set this flag [above](#flags) to see how well getML incoporates such starightforward information into its feature logic.

# %%
if USE_FIRST_NAMES:
    actors.set_role("first_name", getml.data.roles.text)
actors
# Out:
#   name         id   target   first_name      last_name            gender
#   role   join_key   target   unused_string   unused_string        unused_string
#      0          2        0   Michael         'babeepower' Viera   M
#      1          3        0   Eloy            'Chincheta'          M
#      2          4        0   Dieguito        'El Cigala'          M
#      3          5        0   Antonio         'El de Chipiona'     M
#      4          6        0   José            'El Francés'         M
#               ...      ...   ...             ...                  ...
# 817713     845461        1   Herdís          Þorvaldsdóttir       F
# 817714     845462        1   Katla Margrét   Þorvaldsdóttir       F
# 817715     845463        1   Lilja Nótt      Þórarinsdóttir       F
# 817716     845464        1   Hólmfríður      Þórhallsdóttir       F
# 817717     845465        1   Theódóra        Þórðardóttir         F
#
#
# 817718 rows x 5 columns
# memory usage: 43.42 MB
# name: actors
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/actors/

# %%
roles.set_role(["actor_id", "movie_id"], getml.data.roles.join_key)
roles.set_role("role", getml.data.roles.text)
roles
# Out:
#    name   actor_id   movie_id   role
#    role   join_key   join_key   text
#       0          2     280088   Stevie
#       1          2     396232   Various/lyricist
#       2          3     376687   Gitano 1
#       3          4     336265   El Cigala
#       4          5     135644   Himself
#                ...        ...   ...
# 3431961     845461     137097   Kata
# 3431962     845462     208838   Magga
# 3431963     845463        870   Gunna
# 3431964     845464     378123   Gudrun
# 3431965     845465     378123
#
#
# 3431966 rows x 3 columns
# memory usage: 87.84 MB
# name: roles
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/roles/

# %%
movies.set_role("id", getml.data.roles.join_key)
movies.set_role(["year", "rank"], getml.data.roles.numerical)
movies
# Out:
#   name         id        year        rank   name
#   role   join_key   numerical   numerical   unused_string
#      0          0        2002       nan     #28
#      1          1        2000       nan     #7 Train: An Immigrant Journey, ...
#      2          2        1971         6.4   $
#      3          3        1913       nan     $1,000 Reward
#      4          4        1915       nan     $1,000 Reward
#               ...         ...        ...    ...
# 388264     412316        1991       nan     "zem blch krlu"
# 388265     412317        1995       nan     "rgammk"
# 388266     412318        2002       nan     "zgnm Leyla"
# 388267     412319        1983       nan     " Istanbul"
# 388268     412320        1958       nan     "sterreich"
#
#
# 388269 rows x 4 columns
# memory usage: 18.37 MB
# name: movies
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/movies/

# %%
movies_genres.set_role("movie_id", getml.data.roles.join_key)
movies_genres.set_role("genre", getml.data.roles.categorical)
movies_genres
# Out:
#   name   movie_id   genre
#   role   join_key   categorical
#      0          1   Documentary
#      1          1   Short
#      2          2   Comedy
#      3          2   Crime
#      4          5   Western
#               ...   ...
# 395114     378612   Adventure
# 395115     378612   Drama
# 395116     378613   Comedy
# 395117     378613   Drama
# 395118     378614   Comedy
#
#
# 395119 rows x 2 columns
# memory usage: 3.16 MB
# name: movies_genres
# type: getml.DataFrame
# url: http://localhost:1709/#/getdataframe/imdb/movies_genres/

# %% [markdown]
# We need to separate our data set into a training, testing and validation set:

# %%
split = getml.data.split.random(train=0.7, validation=0.15, test=0.15)
split
# Out:
#
#  0   train
#  1   validation
#  2   train
#  3   validation
#  4   validation
#      ...
#
#
# infinite number of  rows
# type: StringColumnView

# %%
container = getml.data.Container(population=actors, split=split)

container.add(
    roles=roles,
    movies=movies,
    movies_genres=movies_genres,
)

container
# Out:
# population
#     subset       name       rows   type
# 0   test         actors   122794   View
# 1   train        actors   571807   View
# 2   validation   actors   123117   View
#
# peripheral
#     name               rows   type
# 0   roles           3431966   DataFrame
# 1   movies           388269   DataFrame
# 2   movies_genres    395119   DataFrame

# %% [markdown]
# ## 2. Predictive modelling
#
# We loaded the data and defined the roles and units. Next, we create a getML pipeline for relational learning.

# %% [markdown]
# ### 2.1 Define relational model
#
# To get started with relational learning, we need to specify the data model.

# %%
dm = getml.data.DataModel("actors")

dm.add(getml.data.to_placeholder(
    roles=roles,
    movies=movies,
    movies_genres=movies_genres,
))

dm.population.join(
    dm.roles,
    on=("id", "actor_id"),
)

dm.roles.join(
    dm.movies,
    on=("movie_id", "id"),
    relationship=getml.data.relationship.many_to_one,
)

dm.movies.join(
    dm.movies_genres,
    on=("id", "movie_id"),
)

dm
# Out:
# actors:
#   columns:
#
#
#   joins:
#   - right: 'roles'
#     on: (actors.id, roles.actor_id)
#     relationship: 'many-to-many'
#     lagged_targets: False
#
# roles:
#   columns:
#   - actor_id: join_key
#   - movie_id: join_key
#   - role: text
#
#   joins:
#   - right: 'movies'
#     on: (roles.movie_id, movies.id)
#     relationship: 'many-to-one'
#     lagged_targets: False
#
# movies:
#   columns:
#   - id: join_key
#   - year: numerical
#   - rank: numerical
#   - name: unused_string
#
#   joins:
#   - right: 'movies_genres'
#     on: (movies.id, movies_genres.movie_id)
#     relationship: 'many-to-many'
#     lagged_targets: False
#
# movies_genres:
#   columns:
#   - genre: categorical
#   - movie_id: join_key

# %% [markdown]
# ### 2.2 getML pipeline

# %% [markdown]
# <!-- #### 2.1.1  -->
# __Set-up the feature learner & predictor__

# %% [markdown]
# We can either use the relboost default parameters or some more fine-tuned parameters. Fine-tuning these parameters in this way can increase our predictive accuracy to 85%, but the training time increases to over 4 hours. We therefore assume that we want to use the default parameters.

# %%
text_field_splitter = getml.preprocessors.TextFieldSplitter()

mapping = getml.preprocessors.Mapping()

fast_prop = getml.feature_learning.FastProp(
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
)

predictor = getml.predictors.XGBoostClassifier()

# %% [markdown]
# __Build the pipeline__

# %%
pipe = getml.pipeline.Pipeline(
    tags=['fast_prop'],
    data_model=dm,
    preprocessors=[text_field_splitter, mapping],
    feature_learners=[fast_prop],
    predictors=[predictor]
)

# %% [markdown]
# ### 2.3 Model training

# %%
pipe.check(container.train)
# Out:
# Checking data model...
#
#
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# Checking...
# [========================================] 100%
#
# INFO [FOREIGN KEYS NOT FOUND]: When joining ROLES__STAGING_TABLE_3 and MOVIES_GENRES__STAGING_TABLE_2 over 'id' and 'movie_id', there are no corresponding entries for 26.899421% of entries in 'id' in 'ROLES__STAGING_TABLE_3'. You might want to double-check your join keys.

# %%
pipe.fit(container.train)
# Out:
# Checking data model...
#
#
# Staging...
# [========================================] 100%
#
# INFO [FOREIGN KEYS NOT FOUND]: When joining ROLES__STAGING_TABLE_3 and MOVIES_GENRES__STAGING_TABLE_2 over 'id' and 'movie_id', there are no corresponding entries for 26.899421% of entries in 'id' in 'ROLES__STAGING_TABLE_3'. You might want to double-check your join keys.
#
#
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# Indexing text fields...
# [========================================] 100%
#
# FastProp: Trying 226 features...
# [========================================] 100%
#
# FastProp: Building subfeatures...
# [========================================] 100%
#
# FastProp: Building features...
# [========================================] 100%
#
# XGBoost: Training as predictor...
# [========================================] 100%
#
# Trained pipeline.
# Time taken: 0h:10m:18.061725
# Pipeline(data_model='actors',
#          feature_learners=['FastProp'],
#          feature_selectors=[],
#          include_categorical=False,
#          loss_function=None,
#          peripheral=['movies', 'movies_genres', 'roles'],
#          predictors=['XGBoostClassifier'],
#          preprocessors=['TextFieldSplitter', 'Mapping'],
#          share_selected_features=0.5,
#          tags=['fast_prop', 'container-JNG9hg'])
#
# url: http://localhost:1709/#/getpipeline/imdb/xJnuhm/0/

# %% [markdown]
# ### 2.4 Model evaluation

# %%
pipe.score(container.test)
# Out:
# Staging...
# [========================================] 100%
#
# Preprocessing...
# [========================================] 100%
#
# FastProp: Building subfeatures...
# [========================================] 100%
#
# FastProp: Building features...
# [========================================] 100%
#     date time             set used   target   accuracy       auc   cross entropy
# 0   2021-08-21 21:43:54   train      target     0.8424    0.9179          0.3205
# 1   2021-08-21 21:44:52   test       target     0.8432    0.9183          0.3213

# %% [markdown]
#  ### 2.5 Productionization
#
# It is possible to productionize the pipeline by transpiling the features into production-ready SQL code.

# %%
pipe.features.to_sql(dialect=getml.pipeline.dialect.spark_sql).save("imdb_spark")

# %%
pipe.features.to_sql().save("imdb_pipeline")

# %%
spark = SparkSession(sc)

# %%
population_spark = container.train.population.to_pyspark(spark, name="actors")

# %%
movies_genres_spark =container.movies_genres.to_pyspark(spark, name="movies_genres")
roles_spark =container.roles.to_pyspark(spark, name="roles")
movies_spark =container.movies.to_pyspark(spark, name="movies")

# %%
getml.spark.execute(spark, "imdb_spark")
# Out:
# 2021-08-21 21:46:59,665 Executing imdb_spark/0001_actors__staging_table_1.sql...
# 2021-08-21 21:47:18,556 Executing imdb_spark/0002_movies_genres__staging_table_2.sql...
# 2021-08-21 21:47:21,307 Executing imdb_spark/0003_roles__staging_table_3.sql...
# 2021-08-21 21:47:54,959 Executing imdb_spark/0004_roles__staging_table_3__role.sql...
# 2021-08-21 21:48:09,956 Executing imdb_spark/0005_genre__mapping_1_1_target_1_avg.sql...
# 2021-08-21 21:48:13,617 Executing imdb_spark/0006_role__mapping_1_2_target_1_avg.sql...
# 2021-08-21 21:48:20,550 Executing imdb_spark/0007_t3__year__mapping_1_target_1_avg.sql...
# 2021-08-21 21:48:33,637 Executing imdb_spark/0008_feature_1_1_1.sql...
# 2021-08-21 21:48:56,972 Executing imdb_spark/0009_feature_1_1_2.sql...
# 2021-08-21 21:49:19,228 Executing imdb_spark/0010_feature_1_1_3.sql...
# 2021-08-21 21:49:33,306 Executing imdb_spark/0011_feature_1_1_4.sql...
# 2021-08-21 21:49:52,487 Executing imdb_spark/0012_feature_1_1_5.sql...
# 2021-08-21 21:50:12,105 Executing imdb_spark/0013_feature_1_1_6.sql...
# 2021-08-21 21:50:25,113 Executing imdb_spark/0014_feature_1_1_7.sql...
# 2021-08-21 21:57:02,733 Executing imdb_spark/0015_feature_1_1_8.sql...
# 2021-08-21 21:57:14,771 Executing imdb_spark/0016_feature_1_1_9.sql...
# 2021-08-21 21:57:45,343 Executing imdb_spark/0017_feature_1_1_10.sql...
# 2021-08-21 21:57:57,802 Executing imdb_spark/0018_feature_1_1_11.sql...
# 2021-08-21 21:58:09,766 Executing imdb_spark/0019_feature_1_1_12.sql...
# 2021-08-21 21:58:21,861 Executing imdb_spark/0020_feature_1_1_13.sql...
# 2021-08-21 21:58:33,398 Executing imdb_spark/0021_feature_1_1_14.sql...
# 2021-08-21 21:58:48,978 Executing imdb_spark/0022_feature_1_1_15.sql...
# 2021-08-21 21:59:04,882 Executing imdb_spark/0023_feature_1_1_16.sql...
# 2021-08-21 21:59:16,118 Executing imdb_spark/0024_feature_1_1_17.sql...
# 2021-08-21 22:05:53,393 Executing imdb_spark/0025_feature_1_1_18.sql...
# 2021-08-21 22:06:05,629 Executing imdb_spark/0026_feature_1_1_19.sql...
# 2021-08-21 22:06:24,193 Executing imdb_spark/0027_feature_1_1_20.sql...
# 2021-08-21 22:06:35,419 Executing imdb_spark/0028_feature_1_1_21.sql...
# 2021-08-21 22:06:46,823 Executing imdb_spark/0029_feature_1_1_22.sql...
# 2021-08-21 22:06:58,587 Executing imdb_spark/0030_feature_1_1.sql...
# 2021-08-21 22:07:16,593 Executing imdb_spark/0031_feature_1_2.sql...
# 2021-08-21 22:07:39,116 Executing imdb_spark/0032_feature_1_3.sql...
# 2021-08-21 22:08:00,111 Executing imdb_spark/0033_feature_1_4.sql...
# 2021-08-21 22:08:18,282 Executing imdb_spark/0034_feature_1_5.sql...
# 2021-08-21 22:09:47,024 Executing imdb_spark/0035_feature_1_6.sql...
# 2021-08-21 22:10:09,744 Executing imdb_spark/0036_feature_1_7.sql...
# 2021-08-21 22:10:27,263 Executing imdb_spark/0037_feature_1_8.sql...
# 2021-08-21 22:10:43,831 Executing imdb_spark/0038_feature_1_9.sql...
# 2021-08-21 22:11:01,774 Executing imdb_spark/0039_feature_1_10.sql...
# 2021-08-21 22:11:22,674 Executing imdb_spark/0040_feature_1_11.sql...
# 2021-08-21 22:11:42,227 Executing imdb_spark/0041_feature_1_12.sql...
# 2021-08-21 22:11:59,151 Executing imdb_spark/0042_feature_1_13.sql...
# 2021-08-21 22:13:28,204 Executing imdb_spark/0043_feature_1_14.sql...
# 2021-08-21 22:13:44,281 Executing imdb_spark/0044_feature_1_15.sql...
# 2021-08-21 22:14:06,413 Executing imdb_spark/0045_feature_1_16.sql...
# 2021-08-21 22:14:23,133 Executing imdb_spark/0046_feature_1_17.sql...
# 2021-08-21 22:14:40,418 Executing imdb_spark/0047_feature_1_18.sql...
# 2021-08-21 22:15:00,685 Executing imdb_spark/0048_feature_1_19.sql...
# 2021-08-21 22:15:21,393 Executing imdb_spark/0049_feature_1_20.sql...
# 2021-08-21 22:15:39,872 Executing imdb_spark/0050_feature_1_21.sql...
# 2021-08-21 22:15:56,611 Executing imdb_spark/0051_feature_1_22.sql...
# 2021-08-21 22:16:19,755 Executing imdb_spark/0052_feature_1_23.sql...
# 2021-08-21 22:16:37,174 Executing imdb_spark/0053_feature_1_24.sql...
# 2021-08-21 22:16:54,626 Executing imdb_spark/0054_feature_1_25.sql...
# 2021-08-21 22:17:24,399 Executing imdb_spark/0055_feature_1_26.sql...
# 2021-08-21 22:17:52,945 Executing imdb_spark/0056_feature_1_27.sql...
# 2021-08-21 22:18:20,614 Executing imdb_spark/0057_feature_1_28.sql...
# 2021-08-21 22:18:46,225 Executing imdb_spark/0058_feature_1_29.sql...
# 2021-08-21 22:23:37,614 Executing imdb_spark/0059_feature_1_30.sql...
# 2021-08-21 22:24:02,417 Executing imdb_spark/0060_feature_1_31.sql...
# 2021-08-21 22:24:32,828 Executing imdb_spark/0061_feature_1_32.sql...
# 2021-08-21 22:24:57,506 Executing imdb_spark/0062_feature_1_33.sql...
# 2021-08-21 22:25:23,681 Executing imdb_spark/0063_feature_1_34.sql...
# 2021-08-21 22:25:54,143 Executing imdb_spark/0064_feature_1_35.sql...
# 2021-08-21 22:26:21,479 Executing imdb_spark/0065_feature_1_36.sql...
# 2021-08-21 22:26:50,711 Executing imdb_spark/0066_feature_1_37.sql...
# 2021-08-21 22:27:19,267 Executing imdb_spark/0067_feature_1_38.sql...
# 2021-08-21 22:27:44,991 Executing imdb_spark/0068_feature_1_39.sql...
# 2021-08-21 22:32:38,769 Executing imdb_spark/0069_feature_1_40.sql...
# 2021-08-21 22:33:03,105 Executing imdb_spark/0070_feature_1_41.sql...
# 2021-08-21 22:33:38,933 Executing imdb_spark/0071_feature_1_42.sql...
# 2021-08-21 22:34:04,666 Executing imdb_spark/0072_feature_1_43.sql...
# 2021-08-21 22:34:31,381 Executing imdb_spark/0073_feature_1_44.sql...
# 2021-08-21 22:35:00,638 Executing imdb_spark/0074_feature_1_45.sql...
# 2021-08-21 22:35:29,736 Executing imdb_spark/0075_feature_1_46.sql...
# 2021-08-21 22:35:59,599 Executing imdb_spark/0076_feature_1_47.sql...
# 2021-08-21 22:36:23,410 Executing imdb_spark/0077_feature_1_48.sql...
# 2021-08-21 22:41:19,373 Executing imdb_spark/0078_feature_1_49.sql...
# 2021-08-21 22:41:45,408 Executing imdb_spark/0079_feature_1_50.sql...
# 2021-08-21 22:42:18,193 Executing imdb_spark/0080_feature_1_51.sql...
# 2021-08-21 22:42:43,375 Executing imdb_spark/0081_feature_1_52.sql...
# 2021-08-21 22:43:09,219 Executing imdb_spark/0082_feature_1_53.sql...
# 2021-08-21 22:43:38,066 Executing imdb_spark/0083_feature_1_54.sql...
# 2021-08-21 22:44:04,757 Executing imdb_spark/0084_feature_1_55.sql...
# 2021-08-21 22:44:33,212 Executing imdb_spark/0085_feature_1_56.sql...
# 2021-08-21 22:45:02,625 Executing imdb_spark/0086_feature_1_57.sql...
# 2021-08-21 22:45:27,358 Executing imdb_spark/0087_feature_1_58.sql...
# 2021-08-21 22:50:23,892 Executing imdb_spark/0088_feature_1_59.sql...
# 2021-08-21 22:50:53,203 Executing imdb_spark/0089_feature_1_60.sql...
# 2021-08-21 22:51:27,399 Executing imdb_spark/0090_feature_1_61.sql...
# 2021-08-21 22:51:54,855 Executing imdb_spark/0091_feature_1_62.sql...
# 2021-08-21 22:52:20,360 Executing imdb_spark/0092_feature_1_63.sql...
# 2021-08-21 22:52:47,014 Executing imdb_spark/0093_feature_1_64.sql...
# 2021-08-21 22:53:18,032 Executing imdb_spark/0094_feature_1_65.sql...
# 2021-08-21 22:53:48,401 Executing imdb_spark/0095_feature_1_66.sql...
# 2021-08-21 22:54:14,906 Executing imdb_spark/0096_feature_1_67.sql...
# 2021-08-21 22:59:14,206 Executing imdb_spark/0097_feature_1_68.sql...
# 2021-08-21 22:59:39,653 Executing imdb_spark/0098_feature_1_69.sql...
# 2021-08-21 23:00:15,090 Executing imdb_spark/0099_feature_1_70.sql...
# 2021-08-21 23:00:40,863 Executing imdb_spark/0100_feature_1_71.sql...
# 2021-08-21 23:01:07,126 Executing imdb_spark/0101_feature_1_72.sql...
# 2021-08-21 23:01:33,496 Executing imdb_spark/0102_feature_1_73.sql...
# 2021-08-21 23:02:02,041 Executing imdb_spark/0103_feature_1_74.sql...
# 2021-08-21 23:02:31,807 Executing imdb_spark/0104_feature_1_75.sql...
# 2021-08-21 23:02:57,063 Executing imdb_spark/0105_feature_1_76.sql...
# 2021-08-21 23:07:59,479 Executing imdb_spark/0106_feature_1_77.sql...
# 2021-08-21 23:08:24,926 Executing imdb_spark/0107_feature_1_78.sql...
# 2021-08-21 23:08:59,794 Executing imdb_spark/0108_feature_1_79.sql...
# 2021-08-21 23:09:25,751 Executing imdb_spark/0109_feature_1_80.sql...
# 2021-08-21 23:09:51,556 Executing imdb_spark/0110_feature_1_81.sql...
# 2021-08-21 23:10:18,593 Executing imdb_spark/0111_feature_1_82.sql...
# 2021-08-21 23:10:47,727 Executing imdb_spark/0112_feature_1_83.sql...
# 2021-08-21 23:11:16,121 Executing imdb_spark/0113_feature_1_84.sql...
# 2021-08-21 23:11:42,752 Executing imdb_spark/0114_feature_1_85.sql...
# 2021-08-21 23:16:40,763 Executing imdb_spark/0115_feature_1_86.sql...
# 2021-08-21 23:17:06,592 Executing imdb_spark/0116_feature_1_87.sql...
# 2021-08-21 23:17:40,491 Executing imdb_spark/0117_feature_1_88.sql...
# 2021-08-21 23:18:06,047 Executing imdb_spark/0118_feature_1_89.sql...
# 2021-08-21 23:18:33,447 Executing imdb_spark/0119_feature_1_90.sql...
# 2021-08-21 23:19:00,712 Executing imdb_spark/0120_feature_1_91.sql...
# 2021-08-21 23:19:29,778 Executing imdb_spark/0121_feature_1_92.sql...
# 2021-08-21 23:19:58,672 Executing imdb_spark/0122_feature_1_93.sql...
# 2021-08-21 23:20:24,058 Executing imdb_spark/0123_feature_1_94.sql...
# 2021-08-21 23:25:28,995 Executing imdb_spark/0124_feature_1_95.sql...
# 2021-08-21 23:25:55,250 Executing imdb_spark/0125_feature_1_96.sql...
# 2021-08-21 23:26:30,407 Executing imdb_spark/0126_feature_1_97.sql...
# 2021-08-21 23:26:57,296 Executing imdb_spark/0127_feature_1_98.sql...
# 2021-08-21 23:27:22,513 Executing imdb_spark/0128_feature_1_99.sql...
# 2021-08-21 23:27:50,933 Executing imdb_spark/0129_feature_1_100.sql...
# 2021-08-21 23:28:19,990 Executing imdb_spark/0130_feature_1_101.sql...
# 2021-08-21 23:28:49,797 Executing imdb_spark/0131_feature_1_102.sql...
# 2021-08-21 23:29:17,206 Executing imdb_spark/0132_feature_1_103.sql...
# 2021-08-21 23:34:24,425 Executing imdb_spark/0133_feature_1_104.sql...
# 2021-08-21 23:34:50,690 Executing imdb_spark/0134_feature_1_105.sql...
# 2021-08-21 23:35:28,094 Executing imdb_spark/0135_feature_1_106.sql...
# 2021-08-21 23:35:55,337 Executing imdb_spark/0136_feature_1_107.sql...
# 2021-08-21 23:36:21,889 Executing imdb_spark/0137_feature_1_108.sql...
# 2021-08-21 23:36:49,838 Executing imdb_spark/0138_feature_1_109.sql...
# 2021-08-21 23:37:19,661 Executing imdb_spark/0139_feature_1_110.sql...
# 2021-08-21 23:37:49,318 Executing imdb_spark/0140_feature_1_111.sql...
# 2021-08-21 23:38:15,319 Executing imdb_spark/0141_feature_1_112.sql...
# 2021-08-21 23:43:22,628 Executing imdb_spark/0142_feature_1_113.sql...
# 2021-08-21 23:43:47,656 Executing imdb_spark/0143_feature_1_114.sql...
# 2021-08-21 23:44:20,244 Executing imdb_spark/0144_feature_1_115.sql...
# 2021-08-21 23:44:46,811 Executing imdb_spark/0145_feature_1_116.sql...
# 2021-08-21 23:45:12,900 Executing imdb_spark/0146_feature_1_117.sql...
# 2021-08-21 23:45:39,059 Executing imdb_spark/0147_feature_1_118.sql...
# 2021-08-21 23:46:07,513 Executing imdb_spark/0148_feature_1_119.sql...
# 2021-08-21 23:46:36,603 Executing imdb_spark/0149_feature_1_120.sql...
# 2021-08-21 23:47:03,154 Executing imdb_spark/0150_feature_1_121.sql...

# %%
spark.sql("SELECT * FROM `ROLES__STAGING_TABLE_3__ROLE`").show()

# %% [markdown]
# ## 3. Conclusion
#
# In this notebook we have demonstrated how getML can be applied to text fields. We have demonstrated the our  approach outperforms state-of-the-art relational learning algorithms on the IMDb dataset.

# %% [markdown]
# ## References
#
# Motl, Jan, and Oliver Schulte. "The CTU prague relational learning repository." arXiv preprint arXiv:1511.03086 (2015).
#
# Neville, Jennifer, and David Jensen. "Relational dependency networks." Journal of Machine Learning Research 8.Mar (2007): 653-692.
#
# Neville, Jennifer, and David Jensen. "Collective classification with relational dependency networks." Workshop on Multi-Relational Data Mining (MRDM-2003). 2003.
#
# Neville, Jennifer, et al. "Learning relational probability trees." Proceedings of the Ninth ACM SIGKDD international conference on Knowledge discovery and data mining. 2003.
#
# Perovšek, Matic, et al. "Wordification: Propositionalization by unfolding relational data into bags of words." Expert Systems with Applications 42.17-18 (2015): 6442-6456.

# %% [markdown]
# # Next Steps
#
# This tutorial went through the basics of applying getML to relational data that contains columns with freeform text. If you want to learn more about getML, here are some additional tutorials and articles that will help you:
#
# __Tutorials:__
# * Just head back to the [notebook overview](welcome.md) and choose one of the remaining examples.
#
# __User Guides__ (from our [documentation](https://docs.getml.com/latest/)):
# * [Feature learning with Multirel](https://docs.getml.com/latest/user_guide/feature_engineering/feature_engineering.html#multirel)
# * [Feature learning with Relboost](https://docs.getml.com/latest/user_guide/feature_engineering/feature_engineering.html#relboost)

# %% [markdown]
# # Get in contact
#
# If you have any question schedule a [call with Alex](https://go.getml.com/meetings/alexander-uhlig/getml-demo), the co-founder of getML, or write us an [email](team@getml.com). Prefer a private demo of getML? Just contact us to make an appointment.
